# %% [markdown]
# ---
#
# # CATEGORICAL DATA TYPE
#
# ---

# %% [markdown]
# **Pandas data types** mostly expand on their base Python and Numpy equivalents
#
# ![image.png](attachment:e5166644-878c-43a8-a1e4-36dcb844c561.png)

# %% [markdown]
# ---
#
# The Pandas **Categorical Data Type** stores text data with repeated values efficiently
#
#     - Python maps each unique category to an integer to save space
#     - As a rule of thumb, only consider this data type when unique categories < number of rows / 2

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Data/retail_2016_2017.csv')
sample_df = df.sample(5, random_state=2023)
sample_df
# Out:
#              id        date  store_nbr               family  sales  \
# 613709  2559653  2016-12-10         29                DAIRY  731.0
# 290251  2236195  2016-06-11         52  HOME AND KITCHEN II    0.0
# 670069  2616013  2017-01-12         10                BOOKS    0.0
# 870367  2816311  2017-05-04          3        PERSONAL CARE  404.0
# 654702  2600646  2017-01-03         29   HOME AND KITCHEN I   30.0
#
#         onpromotion
# 613709           15
# 290251            0
# 670069            0
# 870367            5
# 654702            7

# %%
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 613709 to 654702
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           5 non-null      int64
#  1   date         5 non-null      object
#  2   store_nbr    5 non-null      int64
#  3   family       5 non-null      object
#  4   sales        5 non-null      float64
#  5   onpromotion  5 non-null      int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 280.0+ bytes

# %%
# Lets convert the "family" column into a "category' data type
sample_df = sample_df.astype({'family':'category'})
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 613709 to 654702
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           5 non-null      int64
#  1   date         5 non-null      object
#  2   store_nbr    5 non-null      int64
#  3   family       5 non-null      category
#  4   sales        5 non-null      float64
#  5   onpromotion  5 non-null      int64
# dtypes: category(1), float64(1), int64(3), object(1)
# memory usage: 457.0+ bytes

# %%
sample_df
# Out:
#              id        date  store_nbr               family  sales  \
# 613709  2559653  2016-12-10         29                DAIRY  731.0
# 290251  2236195  2016-06-11         52  HOME AND KITCHEN II    0.0
# 670069  2616013  2017-01-12         10                BOOKS    0.0
# 870367  2816311  2017-05-04          3        PERSONAL CARE  404.0
# 654702  2600646  2017-01-03         29   HOME AND KITCHEN I   30.0
#
#         onpromotion
# 613709           15
# 290251            0
# 670069            0
# 870367            5
# 654702            7

# %% [markdown]
# ---
#
# # LABORATORY
#
# ---

# %%
retail = pd.read_csv('Data/retail_2016_2017.csv')
retail.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054944 entries, 0 to 1054943
# Data columns (total 6 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   id           1054944 non-null  int64
#  1   date         1054944 non-null  object
#  2   store_nbr    1054944 non-null  int64
#  3   family       1054944 non-null  object
#  4   sales        1054944 non-null  float64
#  5   onpromotion  1054944 non-null  int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 151.7 MB

# %%
retail.family.value_counts()
# Out:
# family
# AUTOMOTIVE                    31968
# BABY CARE                     31968
# BEAUTY                        31968
# BEVERAGES                     31968
# BOOKS                         31968
# BREAD/BAKERY                  31968
# CELEBRATION                   31968
# CLEANING                      31968
# DAIRY                         31968
# DELI                          31968
# EGGS                          31968
# FROZEN FOODS                  31968
# GROCERY I                     31968
# GROCERY II                    31968
# HARDWARE                      31968
# HOME AND KITCHEN I            31968
# HOME AND KITCHEN II           31968
# HOME APPLIANCES               31968
# HOME CARE                     31968
# LADIESWEAR                    31968
# LAWN AND GARDEN               31968
# LINGERIE                      31968
# LIQUOR,WINE,BEER              31968
# MAGAZINES                     31968
# MEATS                         31968
# PERSONAL CARE                 31968
# ...

# %%
retail = retail.astype({'family':'category'})
retail.dtypes
# Out:
# id                int64
# date             object
# store_nbr         int64
# family         category
# sales           float64
# onpromotion       int64
# dtype: object

# %%
retail.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054944 entries, 0 to 1054943
# Data columns (total 6 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   id           1054944 non-null  int64
#  1   date         1054944 non-null  object
#  2   store_nbr    1054944 non-null  int64
#  3   family       1054944 non-null  category
#  4   sales        1054944 non-null  float64
#  5   onpromotion  1054944 non-null  int64
# dtypes: category(1), float64(1), int64(3), object(1)
# memory usage: 92.6 MB

# %% [markdown]
# ---
#
# The new DataFrame with the `family` column as **categorical** data type it allows to **reduce the memory usage in almost 39%**. And `now it uses 61% of the original amount of RAM memory`.
#
# ---
