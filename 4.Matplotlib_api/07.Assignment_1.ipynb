# %% [markdown]
# ---
#
# # ASSIGNMEN: FORMATTED CHART
#
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
oil= pd.read_csv('Data/oil.csv', parse_dates=['date']).set_index('date').dropna()
oil = oil.rename(columns={'dcoilwtico':'Oil Price'})
oil
# Out:
#             Oil Price
# date
# 2013-01-02      93.14
# 2013-01-03      92.97
# 2013-01-04      93.12
# 2013-01-07      93.20
# 2013-01-08      93.21
# ...               ...
# 2017-08-25      47.65
# 2017-08-28      46.40
# 2017-08-29      46.46
# 2017-08-30      45.96
# 2017-08-31      47.26
#
# [1175 rows x 1 columns]

# %%
sns.set_style('darkgrid')

oil.plot(title='Oil Price 2013-2017',
        xlabel='Date',
        ylabel='USD Price',
        color='black')
# Out:
# <Axes: title={'center': 'Oil Price 2013-2017'}, xlabel='Date', ylabel='USD Price'>
