# %% [markdown]
# ---
#
# # EXPORTING TO FLAT FILES
#
# ---

# %% [markdown]
# >---
# >The `.to_csv()` and `.to_excel()` methods let you **export DataFrames** to flat files

# %% [markdown]
# ![image.png](attachment:2db74750-d21b-4065-9947-2b9df9f20ada.png)

# %% [markdown]
# <br><br>
#
# ---
#
# <br><br>

# %% [markdown]
# ![image.png](attachment:a878c85f-6fa5-498e-a4d4-2fa1f72fb4cf.png)
